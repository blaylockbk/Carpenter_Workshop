# %% [markdown]
# **Brian Blaylock**
# *September 20, 2021*
#
# # 🗺 Add common features to your maps with `cartopy_tools2`
# When I first learned cartopy, it was difficult to know how to add things to a map. Now that I am more experienced, I know what I like to put on my maps to build the base layer. Instead of recoding all these tasks of adding different features, I simplified and put all these feature layers into functions in my `common_features` class. Now I can create a cartopy axes and add different features to it, or add features to an existing cartopy axes.
#
# One common line I dislike typing so much is `ccrs.PlateCarree()`. Lucky for you, this value is stored in the variable `pc` in cartopy_tools and can be imported.

# %%
import matplotlib.pyplot as plt

from toolbox.cartopy_tools2 import common_features, pc, ccrs

# %%
ax = (
    common_features("50m", dpi=200, dark=True, add_coastlines=False, verbose="debug")
    .COASTLINES(linewidth=.75)
    .STATES(linewidth=.66, edgecolor='b')
    .BORDERS()
    .RIVERS()
    .OCEAN()
    .COUNTIES(linewidth=.33)
    #.LAND()
    .LAKES()
    .TIMEZONE()
    .ax
)
ax.scatter(-115, 40)
ax.center_extent(state="nv")
# Out:
# 🌎 The current axes is not a cartopy axes. Will create a new cartopy axes with crs=<class 'cartopy.crs.PlateCarree'>.
# 🐛 COASTLINES: {'edgecolor': '.5', 'linewidth': 0.75, 'zorder': 100, 'facecolor': 'none'}
# 🐛 STATES: {'edgecolor': 'b', 'linewidth': 0.66, 'alpha': 0.15}
# 🐛 BORDERS: {'edgecolor': '.5', 'linewidth': 0.5}
# 🐛 RIVERS: {'color': '#0f2b38', 'edgecolor': '.5', 'linewidth': 0.75}
# 🐛 OCEAN: {'facecolor': '#0f2b38', 'edgecolor': 'none', 'linewidth': 0.75}
# 🐛 COUNTIES: {'edgecolor': '.5', 'linewidth': 0.33, 'alpha': 0.15}
# 🐛 LAKES: {'edgecolor': '.5', 'facecolor': '#0f2b38', 'linewidth': 0}
# 🐛 TIMEZONE: {'edgecolor': '.5', 'linewidth': 0.2, 'facecolor': 'none', 'linestyle': ':'}
# (-121.65435595238647,
#  -111.65435595238648,
#  34.35482764691297,
#  44.35482764691297)
# /p/home/blaylock/anaconda3/envs/basic38/lib/python3.8/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
# ...

# %%
ax.add_feature(feature.parks_and_protected_lands
# Out:
#   File "<ipython-input-6-7d7f0426e10d>", line 1
#     ax.add_feature(feature.parks_and_protected_lands
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
m = common_features(dpi=300)
f = feature.NaturalEarthFeature("cultural", "time_zones", "10m")
m.ax.add_feature(f, linewidth=.2, edgecolor='.5', facecolor='none', linestyle=':')

# %%
dir(f)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_crs',
#  '_kwargs',
#  '_validate_scale',
#  'category',
#  'crs',
#  'geometries',
#  'intersecting_geometries',
#  'kwargs',
#  'name',
#  'scale',
#  'scaler',
#  'with_scale']

# %%
m = common_features(dark=False, crs=ccrs.Geostationary(central_longitude=-100))
m.STATES()
#m.BORDERS()
#m.COUNTIES()
m.STAMEN(zoom=2)
#m.ax.center_extent(state='UT')
#m.LAND()
#m.OCEAN()
#m.ROADS(edgecolor='b')
#m.ax.center_extent(state='UT')
m.ax.scatter(-115,45, transform=pc)
m.ax.set_global()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ee7ec3035a69> in <module>
# ----> 1 m = common_features(dark=False, crs=ccrs.Geostationary(central_longitude=-100))
#       2 m.STATES()
#       3 #m.BORDERS()
#       4 #m.COUNTIES()
#       5 m.STAMEN(zoom=2)
#
# TypeError: __new__() got an unexpected keyword argument 'dark'

# %%
fig = plt.figure(figsize=(12, 9))
ax1 = fig.add_subplot(1, 3, 1, projection=pc)
ax2 = fig.add_subplot(1, 3, 2, projection=ccrs.Geostationary(central_longitude=-100))
ax3 = fig.add_subplot(1, 3, 3, projection=ccrs.LambertConformal())

common_features('10m', ax=ax1, dpi=200).RIVERS(color='b')
common_features(ax=ax2)
common_features(ax=ax3)

ax1.center_extent(state='UT')

# %%
m1.STATES
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-25a85dcd29cb> in <module>
# ----> 1 m1.STATES
#
# AttributeError: 'GeoAxesSubplot' object has no attribute 'STATES'

# %%
m = common_features(figsize=[10,10], dpi=200)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6125936af6ee> in <module>
#       4     def __new__(cls):
#       5         return self
# ----> 6 T()
#
# <ipython-input-9-6125936af6ee> in __new__(cls)
#       3         print(a)
#       4     def __new__(cls):
# ----> 5         return self
#       6 T()
#
# NameError: name 'self' is not defined
