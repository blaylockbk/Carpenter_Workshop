# %% [markdown]
# **Brian Blaylock**
# *March 23, 2021*
#
# # NWS Standard Color Curves (2018)

# %%
from paint.standard2 import *

# %%
cm = [cm_wind, cm_tmp, cm_rh, cm_cloud, cm_dpt, cm_pcp, cm_pop, cm_rh, 
      cm_snow, cm_wave_height]
for c in cm:
    c().display()
    if c == cm_pop:
        c(ptype='ice').display()
        c(ptype='snow').display()
